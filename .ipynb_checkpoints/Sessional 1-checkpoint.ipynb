# %%
import os
from nltk.tokenize import WordPunctTokenizer
import time
import re
from collections import Counter
import matplotlib.pyplot as plt

# %%
PATH_TO_CORPUS="F:\\IR Lab\\classics\\"
filenames = os.listdir(PATH_TO_CORPUS)
filenames
# Out:
# ['black-beauty.txt',
#  'coral-island.txt',
#  'great expectations.txt',
#  'gullivers-travels.txt',
#  'hucleberry-finn.txt',
#  'jane-eyre.txt',
#  'kidnapped.txt',
#  'little-women.txt',
#  'oliver-twist.txt',
#  'robinson-crusoe.txt',
#  'swiss family robinson.txt',
#  'treasure-island.txt']

# %% [markdown]
# #### 1. Read in the Classic corpus into a list, where each text should be an entry into the list. Roughly how long does it take to read in the entire corpus. You can answer in absolute time.

# %%
all = []

start = time.time()
for data in filenames:
    try:
        alltext = open(PATH_TO_CORPUS+data ,"r" , encoding = "utf-8").read()
        all.append(alltext)
    except:
        print("read character encoding error")
end = time.time()
print("time : ", (end - start)*1000, " ms ")
# Out:
# time :  54.3673038482666  ms

# %%
len(all)
# Out:
# 12

# %% [markdown]
# #### 2. Repeat the process using the bbc dataset. However, files inside the folders need to be added to the same list. How long did it take to read the dataset?

# %%
path_to_bbc = "F:\\IR Lab\\bbc\\"

start = time.time()
bbc = []
ans = 0
subfolder_names = os.listdir(path_to_bbc)
for subfolder in subfolder_names:
    if os.path.isdir(path_to_bbc + subfolder):
        textfiles = os.listdir(path_to_bbc + subfolder +"\\")
        bbcfile = []
        for data in textfiles:
            #print(path_to_bbc + subfolder + "\\" + data)
            try:
                alltext_1 = open(path_to_bbc + subfolder + "\\" + data,"r",encoding="utf-8").read()
                all.append(alltext_1)
                ans = ans + 1
                bbcfile.append(alltext_1)
            except:
                print("error")
        if len(bbcfile) != 0:
            bbc.append(bbcfile)
            
            
end = time.time()
print("time : ", (end - start)*1000, " ms ")
# Out:
# error
# time :  378.3278465270996  ms

# %% [markdown]
# #### 3. Use the bbc dataset for this problem. How many raw tokens can you identify? A raw token is obtained by segmenting on a blank space. Any punctuations are retained. Multiple consecutive white spaces are to be collapsed into a single white space.

# %%
tokens = []
for file in bbc:
    for text in file:
        tst = re.sub(r'\s+', ' ', text)
        tokens.extend(tst.split(" "))

tokens = list(set(tokens))

# %%
print("Count of Token : ", len(tokens))
# Out:
# Count of Token :  65539

# %% [markdown]
# #### 4. Produce a list of better quality tokens for the documents in the bbc dataset. The tokens are now defined as follows:
#
# #### ”A Token is a collection of alphabets and/or digits with a (optional) single instance of an apostrophe or a hyphen.”

# %%
pattern = re.compile(r"^\w*[-']?\w*$")
better_tokens = list(filter(pattern.match, tokens))
better_tokens = [i for i in better_tokens if len(i) != 0]

# %%
better_tokens
# Out:
# ['incident',
#  'Wilmslow',
#  '182',
#  'irritate',
#  'four-set',
#  'Helmut',
#  'disk',
#  'keys',
#  '330m',
#  'Spirit',
#  'ill-equipped',
#  'city',
#  'male-orientated',
#  'skeletal',
#  'define',
#  'Blackburn',
#  "Hitchhiker's",
#  'pave',
#  'underneath',
#  'grinds',
#  'clutches',
#  'Bristol',
#  'chord',
#  'Mardell',
#  'Marja',
#  'Grass',
#  'black',
#  'Cinematographer',
#  'Lundgren',
#  'far-flung',
#  'muddled',
#  '4Children',
#  'Soccer',
#  'assassinated',
#  "You're",
#  'must-have',
#  'Chia',
#  'wagging',
#  'duplicate',
#  'forcible',
#  "Kashyap's",
#  'Dermot',
#  'clinches',
#  'fansite',
#  'Sarbanes',
#  'simulate',
#  'wider',
#  'conservative',
#  'UKA',
#  'aid-related',
#  'widened',
#  'Big',
#  'sometime',
#  'pace',
#  'Calvin',
#  'founding',
#  'polish',
#  'Wieting',
#  'mid-market',
#  'Abbas',
#  '191',
#  'gospel',
#  'eyeing',
#  "U2's",
#  'contemporary',
#  'apart',
#  'Clutterbuck',
#  'disciplines',
#  'procreative',
#  'ballerinas',
#  "'acts",
#  'trawlers',
#  'repayments',
#  'out-thought',
#  'Boyle',
#  'Commentators',
#  'privacy',
#  'hard-line',
#  'exceeds',
#  "Robbies'",
#  'procedure',
#  'Praising',
#  'Shawn',
#  'semi-professional',
#  'Osbournes',
#  'cartilage',
#  'Fightstar',
#  'teetered',
#  'Schweitzer',
#  'Limiting',
#  'persons',
#  "performer's",
#  'Inanimate',
#  'DDoS',
#  'Remy',
#  'stealth',
#  'happens',
#  'sweatshops',
#  'budget',
#  'garbage',
#  'North',
#  'Spurlock',
#  'woods',
#  'Red',
#  'Portishead',
#  'Assistant',
#  'Welling',
#  'slipped',
#  'tens',
#  'ABN',
#  'Spanglish',
#  'Dougray',
#  'defeatism',
#  'blames',
#  'protecting',
#  'Futureheads',
#  'yellow',
#  'Vice',
#  'credibility',
#  'negatives',
#  'evaded',
#  "Thackeray's",
#  '1963',
#  "they'll",
#  'over-complicated',
#  'Flamini',
#  'military',
#  'plugging',
#  'Buntes',
#  'Statistic',
#  'Duncan',
#  'SCH-V770',
#  'Kuwait',
#  'Anyone',
#  'signalling',
#  "Makarov's",
#  'Lynn',
#  'has',
#  'units',
#  'Claims',
#  'stood',
#  'Side',
#  'Williams',
#  'bests',
#  'customary',
#  'bundling',
#  'ultra-wideband',
#  'Lamine',
#  'rulings',
#  'convert',
#  'omission',
#  'ex-boss',
#  'rattling',
#  'wide-angle',
#  'hood',
#  'un-British',
#  'resurrected',
#  'Vision',
#  'affects',
#  'execute',
#  'cinematography',
#  'Vickery',
#  'Zurich',
#  'senior',
#  'grow',
#  'Sachs',
#  'Dave',
#  'learners',
#  'happy',
#  'Loop',
#  'technology',
#  'buy-back',
#  'Lambert',
#  "radio's",
#  'Lomana',
#  'irritated',
#  'werewolf',
#  'displace',
#  'road',
#  'Dec',
#  'Carwyn',
#  'Files',
#  "Blunkett's",
#  'aspect',
#  'disseminated',
#  'Indian-administered',
#  'hijack',
#  'poisonous',
#  'Japanese',
#  'million',
#  'acknowledges',
#  'Is',
#  'stream',
#  "Zealand's",
#  'Hertfordshire',
#  'incidence',
#  "didn't",
#  'Morpeth',
#  'June',
#  'fairground',
#  'Canada',
#  'Anita',
#  'indeed',
#  'hike',
#  'Guardsman',
#  'Down',
#  'phenomenally',
#  "Rover's",
#  'ousted',
#  'contribute',
#  'Wolong',
#  'Nicholson',
#  'Fletcher',
#  'residence',
#  "Telecom's",
#  'stirred',
#  "Mousa's",
#  'Darling',
#  'situations',
#  'juries',
#  'C4',
#  "eat'",
#  'Iranian',
#  'Whenever',
#  'handling',
#  'Atlantic',
#  '1815',
#  'punishment',
#  'disappearing',
#  'Aidan',
#  'laser-based',
#  'Tobacco',
#  'panicky',
#  '24th',
#  'certainty',
#  'Tools',
#  'imaging',
#  'zombie',
#  'Alfonso',
#  'halls',
#  'Adopting',
#  'Supply',
#  'preview',
#  'Previously',
#  'researcher',
#  "Airway's",
#  'unravelling',
#  'confirmation',
#  'boosting',
#  'outcry',
#  'centring',
#  'notebook',
#  'crisper',
#  "Springsteen's",
#  '45-6',
#  'Des',
#  'homophobic',
#  'Riccardo',
#  'UFJ-MTFG',
#  'vein',
#  '16s',
#  'suspense-filled',
#  'Reidar',
#  'Guinness',
#  'savage',
#  'infects',
#  'setback',
#  'unaffected',
#  'Derval',
#  'enliven',
#  'Chennai-based',
#  'Portal',
#  "risk'",
#  'Bless',
#  'Robbins',
#  'best-of',
#  'passing',
#  'Velimir',
#  'disadvantage',
#  'cocktail',
#  'Wholesale',
#  'squabbling',
#  'redemptions',
#  'hinting',
#  'J-Lo',
#  'compromised',
#  'Albanian',
#  'Serna',
#  'regretting',
#  'Hanover',
#  'Commerzbank',
#  'Brandon',
#  'Scott',
#  '24-hour',
#  'cinemas',
#  'Together',
#  'holy',
#  'results',
#  'substituted',
#  'Tom',
#  'capitalising',
#  'Burrell',
#  'steady',
#  'dissatisfaction',
#  'Annies',
#  'vociferously',
#  'rallies',
#  'transplanted',
#  'retained',
#  '142',
#  'Raj',
#  'Finn',
#  'hereditary',
#  'synthesised',
#  'incomes',
#  'Blizzard',
#  'frayed',
#  'evicted',
#  'funereal',
#  'derailed',
#  'I',
#  '32nd',
#  'financings',
#  'misled',
#  'white-tail',
#  'merry',
#  'Arabic',
#  "viewer's",
#  'Blige',
#  'LOL',
#  'Menatep',
#  'Cheating',
#  'Kristiansen',
#  'Kilo',
#  'owing',
#  'dithers',
#  'Hepatitis',
#  'Petr',
#  'Nasdaq',
#  'newest',
#  'Welsh-English',
#  'DSL',
#  'metres',
#  'expressing',
#  "sun's",
#  'zone',
#  'appreciate',
#  'Macrovision',
#  'Andy',
#  'midstream',
#  'worn',
#  'interviewed',
#  'Laulala',
#  'Wyn',
#  'Justyna',
#  'Nemeth',
#  'pleasantly',
#  'workforce',
#  'save',
#  'haves',
#  '140',
#  'Gielgud',
#  'Games',
#  'downturn',
#  'boardroom',
#  "'are",
#  'outperformance',
#  'Porsche',
#  'halve',
#  'Hypertag',
#  'Kidney',
#  'covet',
#  'sells',
#  "airline's",
#  'township',
#  'patchy',
#  'Scream',
#  'welcoming',
#  'Mississippi',
#  'editors',
#  'Looks',
#  'fetched',
#  'next',
#  "Government's",
#  'joined-up',
#  'fascinate',
#  'Welshman',
#  'stain-resistant',
#  'Mosquito',
#  'turning',
#  'commanding',
#  'VAT',
#  'choked',
#  "'Golden",
#  "5'",
#  'Topics',
#  '49-match',
#  'commercialised',
#  'bottle',
#  'sweet-natured',
#  'Ascenders',
#  'sell-offs',
#  'substitute',
#  'celebrate',
#  'Agency',
#  'gentlemen',
#  'disrupted',
#  'which',
#  'Raul',
#  'demolished',
#  'night',
#  'Names',
#  'jealous',
#  'HCL',
#  'soybean',
#  'Explaining',
#  'throughputs',
#  'eviction',
#  'sclerosis',
#  'school-leavers',
#  'Sittingbourne',
#  'stand-off',
#  'sending',
#  'Combining',
#  'emulators',
#  "Starbuck's",
#  'deliberation',
#  'NHTCU',
#  'Parent',
#  'wonderfully',
#  'Whittingdale',
#  "maker's",
#  'Hot',
#  'multi-cultural',
#  'detailed',
#  'Neumi',
#  'Survivors',
#  'proportionate',
#  'frighten',
#  'Finnan',
#  'ex-chatshow',
#  'Llwyd',
#  'Giants',
#  'legality',
#  'Walton',
#  'Swansea-born',
#  'really',
#  'NOT',
#  'Building',
#  'Cyprus',
#  'hush',
#  'domination',
#  'exists',
#  'bullying',
#  'with-profit',
#  'late',
#  'Nattrass',
#  'basking',
#  'water',
#  'Lakomskis',
#  'Fourth',
#  'Intellectual',
#  'rainy',
#  'Schnyder',
#  'accepted',
#  'lasers',
#  'placebo',
#  "Telegraaf's",
#  'co-wrote',
#  'Vaccines',
#  'profile',
#  'furiously',
#  'Maldives',
#  'sweeps',
#  'Called',
#  'Envisional',
#  'Bebe',
#  'Solutions',
#  'reshape',
#  'Adult',
#  'illustrious',
#  'Notes',
#  'overstepping',
#  'Fisheries',
#  'delay',
#  'Bicester',
#  'Peugeot',
#  "tabloids'",
#  'Carstairs',
#  'sting',
#  'transformers',
#  'hardliners',
#  'parade',
#  'pre-conditions',
#  'nearly',
#  "sides'",
#  'got',
#  'Probably',
#  'outsiders',
#  'mansion',
#  'bookrunners',
#  'Scannell',
#  "Minister's",
#  'degree',
#  'Minutes',
#  'revelation',
#  'Oaten',
#  'managing',
#  'Taran',
#  'When',
#  'Stability',
#  'sadly',
#  'Bird',
#  "sterling's",
#  'Headlines',
#  'simulating',
#  'broadening',
#  "NAO's",
#  'Apart',
#  'Conflict',
#  'apace',
#  "Hoon's",
#  'Electrolux',
#  'secure',
#  'retreated',
#  'monitor',
#  'Jeannie',
#  'equivalent',
#  'threshold',
#  '162',
#  'so-and',
#  'enveloping',
#  'Infrastructure',
#  'Peres',
#  'shooters',
#  'Revenues',
#  'archive',
#  'solicitor',
#  "Warriors'",
#  'Gardener',
#  "Seagate's",
#  'Milanesi',
#  'beige',
#  'come',
#  'posts',
#  'Clapton',
#  "Providers'",
#  'fourfold',
#  'gadgets',
#  "Milan's",
#  'conversations',
#  'Scare',
#  "BAA's",
#  'onshore',
#  'Weaver',
#  'graduates',
#  'discounts',
#  'scenes',
#  'merger',
#  'PDAs',
#  'AirAsia',
#  'full-contact',
#  'Gun',
#  'Charlene',
#  'projectors',
#  'Gangs',
#  '925p',
#  'track',
#  'parole',
#  'Ebay',
#  'pledging',
#  'Cosmetic',
#  'Worldcom',
#  'Broadcast',
#  'obsessively',
#  'Jurors',
#  'clamours',
#  'Tsutsumi',
#  'critic',
#  'McDonagh',
#  'Olivier',
#  'TW',
#  "Begg's",
#  'AFP',
#  'standby',
#  '6km',
#  'say-so',
#  'Fallon',
#  'Pendleton',
#  'accepting',
#  'versatile',
#  'able',
#  'Amstel',
#  'rugby',
#  "Andreas'",
#  'solidity',
#  'legisation',
#  'quit',
#  'Tanzi',
#  'process',
#  'Rund',
#  'phonecam',
#  'marketers',
#  "moment's",
#  'youths',
#  'Malian',
#  'Kiely',
#  'Allan',
#  'scrummaging',
#  'admired',
#  'blushes',
#  'Fenerbahce',
#  'welfare',
#  'Copper',
#  "'something",
#  'taxi',
#  'Long',
#  'glimpse',
#  'supremely',
#  'disproportionate',
#  'McIlory',
#  'Tuidriva',
#  'or',
#  "Corelli's",
#  'trading',
#  'policymakers',
#  "borrowers'",
#  'scrapping',
#  'Kanye',
#  'Mansfield',
#  'embarrassed',
#  'mimicked',
#  'Dreamliner',
#  'thinly-disguised',
#  'Darth',
#  'earn',
#  'occasional',
#  'McCourt',
#  "England's",
#  'put-upon',
#  'career-best',
#  'smaller',
#  'Catweazle',
#  'latest',
#  'calorie-heavy',
#  'Hi-Tech',
#  'Hewlett-Packard',
#  'Jordan',
#  'flow',
#  "Paterson's",
#  'experiment',
#  'negotiations',
#  'bravado',
#  'autobiographical',
#  'knee',
#  'Abebe',
#  'Connacht',
#  'challenged',
#  'game-winning',
#  'misery',
#  'bribing',
#  'postgraduates',
#  'tremble',
#  'cheque',
#  'Goldman',
#  "Mandaric's",
#  'triumphant',
#  'synergies',
#  'Guillermo',
#  'bringing',
#  'proven',
#  'receivable',
#  'Boris',
#  'pursue',
#  'Across',
#  'Ti',
#  'docu-drama',
#  'Alumnia',
#  'testimonies',
#  'Kronawitter',
#  'millennium',
#  'blurring',
#  'Katherine',
#  'outline',
#  'Fusiliers',
#  'sprinters',
#  'pits',
#  'predominately',
#  'Pullman',
#  'Candy',
#  '52',
#  'indecision',
#  'Feature',
#  'tedious',
#  'Concern',
#  'Carolina',
#  'Stolichnaya',
#  'regulation',
#  'worthy',
#  'Kremlin',
#  'unsatisfying',
#  'Eyes',
#  'leeks',
#  'athletics-loving',
#  'heritage',
#  'garage',
#  'fertilizers',
#  'jersey',
#  "Gibson's",
#  'demonstrated',
#  'silenced',
#  'Appleton',
#  'Muriel',
#  'unseen',
#  'Pompeii',
#  'Immigration',
#  'Lankans',
#  'Annuity',
#  'Paule',
#  'confined',
#  'presses',
#  'privatisations',
#  'Atomic',
#  'braking',
#  'Baa-Baas',
#  'trans-Atlantic',
#  'pooling',
#  'fisheries',
#  'KFB',
#  "Meldrum's",
#  'Samuel',
#  'Highland',
#  'six-year',
#  'lovers',
#  "Hughes'",
#  'stunned',
#  'trophy',
#  'error',
#  'gaffe',
#  "'le",
#  'iron',
#  'Zomba',
#  'Sleepy',
#  'Collecting',
#  'nun',
#  'headmaster',
#  'Aaliyah',
#  'Josef',
#  'had',
#  'rehashing',
#  "Symbian's",
#  "Britain's",
#  'warns',
#  "Greens'",
#  'War',
#  'Limits',
#  'theoretical',
#  'requirements',
#  'combat',
#  "Saturday's",
#  'Riley',
#  'Antonio',
#  'ranking',
#  'Imagine',
#  'Diehard',
#  "Peru's",
#  'Who',
#  "producer's",
#  'fully-fit',
#  'Scare-mongering',
#  'unhappy',
#  'stalling',
#  'systematically',
#  'Scholls',
#  'Caribbean',
#  '55th',
#  'Highlands',
#  'updates',
#  'dance',
#  'concept',
#  "McKee's",
#  'smoked',
#  'correctly',
#  'breezes',
#  'hitches',
#  'First-choice',
#  'road-trip',
#  'headline',
#  'Sessions',
#  'consensus',
#  'Jarre',
#  'outset',
#  'approach',
#  'fixings',
#  'Prop',
#  'Lots',
#  'downward',
#  'slot',
#  'Jupiter',
#  'nutritional',
#  'resilience',
#  'calls',
#  'vague',
#  'entities',
#  'safeguards',
#  'star-studded',
#  'faith-based',
#  'Lil',
#  'Du',
#  'prevented',
#  "ITV's",
#  'Regent',
#  'Faroe',
#  'divisions',
#  'powering',
#  'pumping',
#  "Motor's",
#  'organs',
#  'apologises',
#  'Directors',
#  'Woolworths',
#  'entrepreneurs',
#  'Niyazov',
#  'entered',
#  'Laying',
#  'expression',
#  'Europe-wide',
#  'motorbike',
#  '150th',
#  'again',
#  'rudimentary',
#  'routed',
#  'Curbishley',
#  'array',
#  'hesitant',
#  'animate',
#  'Standing',
#  'Ella',
#  'angrily',
#  'clashed',
#  'Skeens',
#  'toppling',
#  'spelling',
#  'Messenger',
#  'auditing',
#  "Hague's",
#  "1995's",
#  'scheduled',
#  'Blunt',
#  'Macaulay',
#  'Maniffesto',
#  'ears',
#  'projecting',
#  'Naoki',
#  "states'",
#  'colliding',
#  'Results',
#  'BBC',
#  'During',
#  'fruits',
#  'Nachison',
#  'economist',
#  "military's",
#  'demerged',
#  "Museum's",
#  'recruit',
#  'NHS',
#  'undergone',
#  'Floor',
#  'twin-engined',
#  'shipments',
#  'rebounds',
#  'Douglas',
#  'disaffection',
#  'detecting',
#  'Pickering',
#  'collegiate',
#  're-spawning',
#  'Al-Walid',
#  'cyber',
#  'brewer',
#  'big-screen',
#  'Dawn',
#  'messages',
#  'TV',
#  'Slimfast',
#  'Nant',
#  'pre-selected',
#  'hazard',
#  'deletion',
#  "Canon's",
#  'Harlequins',
#  'orchestrating',
#  'expenditure',
#  'confuse',
#  'Oriel',
#  '831',
#  "America's",
#  'barrel',
#  'iMP',
#  'swears',
#  'upward',
#  'Nanoscale',
#  'Garrow',
#  'Temple',
#  'race',
#  'Bailin',
#  'cartridge',
#  "Dragon's",
#  'trimming',
#  'Euro-Africa',
#  'jackpot',
#  'unbiased',
#  'crop',
#  'caps',
#  'soy',
#  'reads',
#  "inmate's",
#  "'confuse",
#  'Parry',
#  'plantation',
#  'flawed',
#  'Lifting',
#  'Rev',
#  'universe',
#  'job',
#  'ducking',
#  'Toulouse',
#  'Created',
#  'T-Mobile',
#  'Danish',
#  "ATI's",
#  'Literally',
#  "Halifax's",
#  'mouthing',
#  'jeered',
#  'Dingolfing',
#  'bidders',
#  'contenders',
#  'trouble-shooting',
#  'Dollar',
#  'SAP',
#  'pre-school',
#  'clam',
#  'partnered',
#  "Israel's",
#  'X5',
#  'snatching',
#  "departure'",
#  'breweries',
#  'three-monthly',
#  'pronouncement',
#  'CEO',
#  'remain',
#  'Miles',
#  'widely',
#  'sandals',
#  'departed',
#  'Samaria',
#  'enquiry',
#  'immersion',
#  'simultaneously',
#  'salacious',
#  'Client',
#  'inpatients',
#  'intellectuals',
#  'Duchy',
#  'Schmaler',
#  '287',
#  "council's",
#  'They',
#  'exist',
#  'rockstars',
#  "commission's",
#  "Sophos'",
#  'Merchants',
#  'spats',
#  'Chassis',
#  'taste',
#  'Arabian',
#  'enjoyed',
#  'shortages',
#  'stellar',
#  'putting',
#  'Elements',
#  'materials',
#  'flautist',
#  'apologised',
#  "barriers'",
#  "Ballantine's",
#  'month-old',
#  'Keith',
#  'Wave',
#  'withdrawn',
#  'die',
#  'PCS',
#  'indicted',
#  "'a",
#  'Hossam',
#  'amibition',
#  ...]

# %% [markdown]
# #### 5. Create a vocabulary for the bbc dataset containing the tokens found in the last exercise.

# %%
bbc_vocab  = set(better_tokens)
bbc_vocab = list(bbc_vocab)

# %%
len(bbc_vocab)
# Out:
# 33769

# %% [markdown]
# #### 6. Write a program that accepts a token and plots a bar graph showing the top 20 documents where the token is present. Top 20 here is defined as per frequency of occurrence

# %%
def tokenize(file_text, limit = 3):
    text = re.sub(r'\s+', ' ', file_text)
    pattern = re.compile(r"^\w*[-']?\w*$")
    better_tokens = list(filter(pattern.match, text.split(" ")))
    token_list = [ele.lower() for ele in better_tokens if len(ele) > limit]
    return Counter(token_list)

# %%
path_to_bbc = "F:\\IR Lab\\bbc\\"

token_freq = {}
file = 0
subfolder_names = os.listdir(path_to_bbc)
for subfolder in subfolder_names:
    if os.path.isdir(path_to_bbc + subfolder):
        textfiles = os.listdir(path_to_bbc + subfolder +"\\")
        for data in textfiles:
            try:
                file_text = open(path_to_bbc + subfolder + "\\" + data,"r",encoding="utf-8").read()
                token_freq[file] = tokenize(file_text,3)
                file = file + 1
            except:
                print("error")
# Out:
# error

# %%
def calc20Max(freq):
    doc_freq = {}
    for key, val in freq.items():
        for k,v in val.items():
            if(k == user_token):
                doc_freq[key] = v

    sorted_freq = sorted(doc_freq.items(), key=lambda x:x[1], reverse=True)
    sorted_freq = dict(sorted_freq)
    # print(sorted_freq)

    docs = list(sorted_freq.keys())
    tfreq = list(sorted_freq.values())
    if(len(sorted_freq) > 20):
        docs = docs[1:21]
        tfreq = tfreq[1:21]
    
    return docs , tfreq

# %%
user_token = input("Enter token to graph : ")
user_token = user_token.lower()
docs , tfreq = calc20Max(token_freq)
import seaborn as sns
fig = plt.figure(figsize = (10, 5))
sns.barplot(x = docs, y = tfreq, color ='maroon',width = 0.4)
fig.autofmt_xdate()
plt.xlabel("Documents")
plt.ylabel("Token Frequency")
plt.title("max Token Frequency in Documents")
plt.show()
# Out:
# Enter token to graph : press

# %%
sns.histplot([len(ele) for ele in bbc_vocab])
plt.show()
